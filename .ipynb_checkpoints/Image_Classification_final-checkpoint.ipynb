# %%
import gradio as gr

# %%
import tensorflow as tf

from tensorflow import keras
from keras import layers
from keras.models import Sequential

import numpy as np
import matplotlib.pyplot as plt

# %%
import pathlib      
dataset_url = "C:/Users/aishwarya.sonawane/Desktop/Image Classification/flower_photos"
data_dir = pathlib.Path(dataset_url)

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 3670

# %%
import PIL
roses = list(data_dir.glob('roses/*'))      # category
print(roses[4])

temp_image = PIL.Image.open(roses[8])
temp_image
# Out:
# C:\Users\aishwarya.sonawane\Desktop\Image Classification\flower_photos\roses\110472418_87b6a3aa98_m.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x241>

# %%
import PIL
tulips= list(data_dir.glob('tulips/*'))      # category
print(tulips[4])

temp_image = PIL.Image.open(tulips[90])
temp_image
# Out:
# C:\Users\aishwarya.sonawane\Desktop\Image Classification\flower_photos\tulips\10163955604_ae0b830975_n.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x276>

# %%
from tensorflow.keras.preprocessing import image_dataset_from_directory

img_height, img_width = 180, 180
train_ds = image_dataset_from_directory(data_dir, validation_split=0.2, subset="training", seed=123, image_size=(img_height, img_width), batch_size=32)
val_ds = image_dataset_from_directory(data_dir, validation_split=0.2, subset="validation", seed=123, image_size=(img_height, img_width), batch_size=32)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.

# %%
import os 
from glob import glob
for i in os.listdir(dataset_url):
    new_loc = os.path.join(dataset_url,i)
    new = new_loc + '\*.jpg'
    images = glob(new)
    print(f'{i}:',len(images))
# Out:
# daisy: 633
# dandelion: 898
# LICENSE.txt: 0
# roses: 641
# sunflowers: 699
# tulips: 799

# %%
class_names = train_ds.class_names
class_names
# Out:
# ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %%
len(train_ds)
# Out:
# 92

# %%
len(val_ds)
# Out:
# 23

# %%
class_names = ['daisy','dandelion','roses','sunflowers','tulips']

# %%
plt.figure(figsize=(10,10))
for images, labels in train_ds.take(2):     
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))       # imshow works with pixeled array only
        plt.title(class_names[labels[i]])
        # plt.axis("off")

# %%
import tensorflow.keras as keras
import tensorflow as tf

# image processing
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img

# model / neural network
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from glob import glob
from tensorflow.keras import layers, models, Sequential
from tensorflow.keras.layers import Rescaling

# %% [markdown]
# ## CNN model

# %%
num_classes = len(class_names)

model = Sequential([
    Rescaling(1./255, input_shape=(img_height, img_width, 3)),
    layers.Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu'),
    layers.MaxPooling2D(),

    layers.Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu'),
    layers.MaxPooling2D(),

    layers.Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu'),
    layers.MaxPooling2D(),

    layers.Flatten(),
    layers.Dense(units=128, activation='relu'),
    layers.Dense(units=num_classes, activation='softmax')
])

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(train_ds, validation_data=val_ds, epochs=10)
# Out:
# Epoch 1/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 123s 1s/step - accuracy: 0.3371 - loss: 1.6017 - val_accuracy: 0.5531 - val_loss: 1.1057
# Epoch 2/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 122s 1s/step - accuracy: 0.5922 - loss: 1.0286 - val_accuracy: 0.6213 - val_loss: 1.0052
# Epoch 3/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 133s 1s/step - accuracy: 0.6725 - loss: 0.8542 - val_accuracy: 0.6049 - val_loss: 1.0116
# Epoch 4/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 143s 2s/step - accuracy: 0.7413 - loss: 0.7152 - val_accuracy: 0.6131 - val_loss: 1.0075
# Epoch 5/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 146s 2s/step - accuracy: 0.8080 - loss: 0.5291 - val_accuracy: 0.6362 - val_loss: 1.1144
# Epoch 6/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 43s 464ms/step - accuracy: 0.8713 - loss: 0.3560 - val_accuracy: 0.6294 - val_loss: 1.3341
# Epoch 7/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 43s 470ms/step - accuracy: 0.9200 - loss: 0.2505 - val_accuracy: 0.5586 - val_loss: 2.0885
# Epoch 8/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 47s 515ms/step - accuracy: 0.9267 - loss: 0.2250 - val_accuracy: 0.6376 - val_loss: 1.7586
# Epoch 9/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 98s 1s/step - accuracy: 0.9688 - loss: 0.0960 - val_accuracy: 0.6144 - val_loss: 1.9140
# Epoch 10/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 51s 555ms/step - accuracy: 0.9835 - loss: 0.0568 - val_accuracy: 0.6144 - val_loss: 2.0958

# %% [markdown]
# ## Inception V3

# %%
epochs= 100
from tensorflow.keras.applications import InceptionV3 # difference btw v1,v2,v3 
model1= Sequential()

pretrained_model= InceptionV3(include_top=False,
                   input_shape=(180,180,3),
                   pooling='avg',classes=5,
                   weights='imagenet')
print(len(pretrained_model.layers))

for layer in pretrained_model.layers:
        layer.trainable=False
model1.add(Rescaling(1./255,input_shape=(180,180,3)))
model1.add(pretrained_model)
model1.add(layers.Flatten())
model1.add(layers.Dense(256, activation='relu'))
model1.add(layers.Dense(128, activation='relu'))
model1.add(layers.Dense(64, activation='relu'))
model1.add(layers.Dense(num_classes,activation='softmax'))
# Out:
# 312

# %%
model1.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0.0001,
    patience=5,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
    start_from_epoch=0
)

# %%
model1.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/100
# C:\Users\aishwarya.sonawane\AppData\Local\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\nn.py:602: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.5837 - loss: 1.0453 - val_accuracy: 0.8243 - val_loss: 0.4936
# Epoch 2/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 86s 932ms/step - accuracy: 0.8521 - loss: 0.4046 - val_accuracy: 0.8297 - val_loss: 0.4793
# Epoch 3/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 85s 924ms/step - accuracy: 0.8928 - loss: 0.2964 - val_accuracy: 0.8515 - val_loss: 0.4804
# Epoch 4/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 85s 929ms/step - accuracy: 0.9100 - loss: 0.2592 - val_accuracy: 0.8283 - val_loss: 0.5600
# Epoch 5/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 89s 965ms/step - accuracy: 0.9224 - loss: 0.2109 - val_accuracy: 0.8147 - val_loss: 0.5610
# Epoch 6/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 89s 971ms/step - accuracy: 0.9412 - loss: 0.1696 - val_accuracy: 0.8515 - val_loss: 0.5060
# Epoch 7/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 89s 967ms/step - accuracy: 0.9575 - loss: 0.1246 - val_accuracy: 0.8529 - val_loss: 0.5514
# Epoch 8/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 84s 911ms/step - accuracy: 0.9672 - loss: 0.0978 - val_accuracy: 0.8351 - val_loss: 0.6161
# Epoch 9/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 84s 910ms/step - accuracy: 0.9690 - loss: 0.0826 - val_accuracy: 0.8474 - val_loss: 0.6447
# Epoch 10/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 86s 940ms/step - accuracy: 0.9870 - loss: 0.0421 - val_accuracy: 0.8406 - val_loss: 0.6785
# Epoch 11/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 88s 955ms/step - accuracy: 0.9881 - loss: 0.0385 - val_accuracy: 0.8460 - val_loss: 0.7689
# Epoch 12/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━
100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 87s 943ms/step - accuracy: 1.0000 - loss: 6.1895e-06 - val_accuracy: 0.8556 - val_loss: 1.5886
# Epoch 84/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 90s 982ms/step - accuracy: 1.0000 - loss: 5.5774e-06 - val_accuracy: 0.8556 - val_loss: 1.5964
# Epoch 85/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 82s 888ms/step - accuracy: 1.0000 - loss: 5.3113e-06 - val_accuracy: 0.8556 - val_loss: 1.6033
# Epoch 86/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 81s 887ms/step - accuracy: 1.0000 - loss: 5.0794e-06 - val_accuracy: 0.8569 - val_loss: 1.6109
# Epoch 87/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 80s 869ms/step - accuracy: 1.0000 - loss: 4.8873e-06 - val_accuracy: 0.8569 - val_loss: 1.6166
# Epoch 88/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 84s 916ms/step - accuracy: 1.0000 - loss: 4.3731e-06 - val_accuracy: 0.8569 - val_loss: 1.6251
# Epoch 89/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 1.0000 - loss: 4.3957e-06 - val_accuracy: 0.8569 - val_loss: 1.6333
# Epoch 90/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - accuracy: 1.0000 - loss: 4.2494e-06 - val_accuracy: 0.8569 - val_loss: 1.6389
# Epoch 91/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 102s 1s/step - accuracy: 1.0000 - loss: 3.8666e-06 - val_accuracy: 0.8569 - val_loss: 1.6466
# Epoch 92/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 93s 1s/step - accuracy: 1.0000 - loss: 3.5838e-06 - val_accuracy: 0.8569 - val_loss: 1.6536
# Epoch 93/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 113s 1s/step - accuracy: 1.0000 - loss: 3.4938e-06 - val_accuracy: 0.8569 - val_loss: 1.6601
# Epoch 94/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 105s 1s/step - accuracy: 1.0000 - loss: 3.1284e-06 - val_accuracy: 0.8569 - val_loss: 1.6673
# Epoch 95/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 100s 1s/step - accuracy: 1.0000 - loss: 3.1096e-06 - val_accuracy: 0.8569 - val_loss: 1.6741
# Epoch 96/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 103s 1s/step - accuracy: 1.0000 - loss: 2.9168e-06 - val_accuracy: 0.8569 - val_loss: 1.6809
# Epoch 97/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 97s 1s/step - accuracy: 1.0000 - loss: 2.9907e-06 - val_accuracy: 0.8583 - val_loss: 1.6874
# Epoch 98/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 98s 1s/step - accuracy: 1.0000 - loss: 2.8116e-06 - val_accuracy: 0.8583 - val_loss: 1.6944
# Epoch 99/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 1.0000 - loss: 2.6183e-06 - val_accuracy: 0.8569 - val_loss: 1.7019
# Epoch 100/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 97s 1s/step - accuracy: 1.0000 - loss: 2.3793e-06 - val_accuracy: 0.8569 - val_loss: 1.7095

# %%
from sklearn.metrics import classification_report

# %%
val_images = []
val_labels = []

for images, labels in val_ds:
    val_images.append(images)
    val_labels.append(labels)

val_images = np.concatenate(val_images)
val_labels = np.concatenate(val_labels)


# print(val_labels)

predictions = model1.predict(val_images)
# print(predictions)
predicted_classes = np.argmax(predictions, axis=1)

print(classification_report(val_labels, predicted_classes, target_names=class_names))
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 752ms/step
#               precision    recall  f1-score   support
#
#       class1       0.93      0.88      0.90       129
#       class2       0.89      0.89      0.89       176
#       class3       0.78      0.80      0.79       120
#       class4       0.88      0.85      0.87       152
#       class5       0.81      0.85      0.83       157
#
#     accuracy                           0.86       734
#    macro avg       0.86      0.85      0.86       734
# weighted avg       0.86      0.86      0.86       734

# %%
from tensorflow.keras.models import load_model
model.save("cnn.keras")
model1.save("inception.keras")

# Load your models
loaded_model = load_model("cnn.keras")
loaded_inception = load_model("inception.keras")

# %%
def predict_image(img):
    img_4d = img.reshape(-1, img_width, img_height, 3)      # 4D coz model trained on multiple 3Ds
    prediction = loaded_inception.predict(img_4d)[0]
    return {class_names[i]: float(prediction[i]) for i in range(num_classes)}

# %%
import numpy as np
from PIL import Image

def load_image(image_path, target_size=(img_width, img_height)):
    img = Image.open(image_path)
    img = img.resize(target_size)
    img_array = np.array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)
    return img_array

def predict_image(image_path):
    img = load_image(image_path)
    predictions = model1.predict(img)[0]
    return {class_names[i]: float(predictions[i]) for i in range(num_classes)}

def test_predict_image(image_path):
    predictions = predict_image(image_path)
    print(predictions)

image_path = r"C:\Users\aishwarya.sonawane\Desktop\Image Classification\flower_photos\tulips\489506904_9b68ba211c.jpg"
image_path_2 = r"C:\Users\aishwarya.sonawane\Desktop\Image Classification\flower_photos\tulips\11746367_d23a35b085_n.jpg"
test_predict_image(image_path)
test_predict_image(image_path_2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# {'daisy': 0.07584934681653976, 'dandelion': 0.07596972584724426, 'roses': 0.3839021623134613, 'sunflowers': 0.03527255728840828, 'tulips': 0.4290061593055725}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# {'daisy': 0.044326767325401306, 'dandelion': 0.030658628791570663, 'roses': 0.4371780455112457, 'sunflowers': 0.03581497445702553, 'tulips': 0.45202159881591797}

# %%
import numpy as np
from PIL import Image

# Define constants
img_width, img_height = 180, 180
def load_image(image_path, target_size=(img_width, img_height)):
    img = Image.open(image_path)
    img = img.resize(target_size)
    img_array = np.array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)
    return img_array

def predict_image(model, image_path):
    img = load_image(image_path)
    predictions = model.predict(img)[0]
    top_indices = predictions.argsort()[-2:][::-1] 
    top_classes = [(class_names[i], float(predictions[i])) for i in top_indices]
    return top_classes

def test_predict_image(model, image_path):
    top_classes = predict_image(model, image_path)
    print(f'Predicted classes for {image_path}:')
    print(f'1st: {top_classes[0][0]}  Accuracy {top_classes[0][1]:.4f}')
    print(f'2nd: {top_classes[1][0]} Accuracy {top_classes[1][1]:.4f}')

image_path = r"C:\Users\aishwarya.sonawane\Desktop\Image Classification\flower_photos\tulips\489506904_9b68ba211c.jpg"
image_path_2 = r"C:\Users\aishwarya.sonawane\Desktop\Image Classification\flower_photos\tulips\11746367_d23a35b085_n.jpg"

test_predict_image(loaded_inception, image_path)
test_predict_image(loaded_inception, image_path_2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Predicted classes for C:\Users\aishwarya.sonawane\Desktop\Image Classification\flower_photos\tulips\489506904_9b68ba211c.jpg:
# 1st: tulips  Accuracy 0.4290
# 2nd: roses Accuracy 0.3839
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Predicted classes for C:\Users\aishwarya.sonawane\Desktop\Image Classification\flower_photos\tulips\11746367_d23a35b085_n.jpg:
# 1st: tulips  Accuracy 0.4520
# 2nd: roses Accuracy 0.4372
